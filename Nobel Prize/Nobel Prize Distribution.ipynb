# %%
# Importing the Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 6)

# %%
# Importing the dataset

dataset = pd.read_csv('nobel_prize_by_winner.csv')

# %%
dataset.head()
# Out:
#     id         firstname  surname        born        died bornCountry  \
# 0  846            Elinor   Ostrom    8/7/1933   6/12/2012         USA
# 1  846            Elinor   Ostrom    8/7/1933   6/12/2012         USA
# 2  783      Wangari Muta  Maathai    4/1/1940   9/25/2011       Kenya
# 3  230  Dorothy Crowfoot  Hodgkin   5/12/1910   7/29/1994       Egypt
# 4  918            Youyou       Tu  12/30/1930  0000-00-00       China
#
#   bornCountryCode         bornCity     diedCountry diedCountryCode  \
# 0              US  Los Angeles, CA             USA              US
# 1              US  Los Angeles, CA             USA              US
# 2              KE            Nyeri           Kenya              KE
# 3              EG            Cairo  United Kingdom              GB
# 4              CN  Zhejiang Ningbo             NaN             NaN
#
#             diedCity  gender    year   category overallMotivation  share  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 972 entries, 0 to 971
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 972 non-null    int64
#  1   firstname          966 non-null    object
#  2   surname            936 non-null    object
#  3   born               946 non-null    object
#  4   died               946 non-null    object
#  5   bornCountry        940 non-null    object
#  6   bornCountryCode    940 non-null    object
#  7   bornCity           938 non-null    object
#  8   diedCountry        601 non-null    object
#  9   diedCountryCode    600 non-null    object
#  10  diedCity           595 non-null    object
#  11  gender             972 non-null    object
#  12  year               966 non-null    float64
#  13  category           966 non-null    category
#  14  overallMotivation  16 non-null     object
#  15  share              966 non-null    float64
# ...

# %%
dataset = dataset.astype({'category' : 'category'})

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 972 entries, 0 to 971
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 972 non-null    int64
#  1   firstname          966 non-null    object
#  2   surname            936 non-null    object
#  3   born               946 non-null    object
#  4   died               946 non-null    object
#  5   bornCountry        940 non-null    object
#  6   bornCountryCode    940 non-null    object
#  7   bornCity           938 non-null    object
#  8   diedCountry        601 non-null    object
#  9   diedCountryCode    600 non-null    object
#  10  diedCity           595 non-null    object
#  11  gender             972 non-null    object
#  12  year               966 non-null    float64
#  13  category           966 non-null    category
#  14  overallMotivation  16 non-null     object
#  15  share              966 non-null    float64
# ...

# %%
for i in dataset.category.cat.categories:
    print(i)
# Out:
# chemistry
# economics
# literature
# medicine
# peace
# physics

# %%
dataset.category.unique()
# Out:
# ['economics', 'peace', 'chemistry', 'medicine', 'literature', 'physics', NaN]
# Categories (6, object): ['economics', 'peace', 'chemistry', 'medicine', 'literature', 'physics']

# %%
dataset_nobel.isnull().sum().plot(kind = 'bar')
plt.show()

# %% [markdown]
# ## Find out the age group which received the most number of nobel prizes.

# %%
dataset['gender'].value_counts()
# Out:
# male      896
# female     50
# org        26
# Name: gender, dtype: int64

# %%
dataset['gender'].value_counts().plot(kind = 'bar')
plt.title("Male VS Female VS Org ")
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Find the trends in number of nobel prizes received by each category in during 1900 to 2020

# %%
dataset['category'].value_counts()
# Out:
# medicine      227
# physics       222
# chemistry     194
# peace         130
# literature    112
# economics      81
# Name: category, dtype: int64

# %%
dataset['category'].value_counts().plot()
plt.show()

# %%
dataset['category'].value_counts().plot(c="Black",ls="--",marker="s",ms=7)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
vis1=sns.distplot(dataset['category'].value_counts())

# %% [markdown]
# ## Find out and plot which continent is having most number of nobel prize recipients

# %%
dataset['country'].value_counts()
# Out:
# USA                                  361
# United Kingdom                        91
# Germany                               51
# France                                40
# Federal Republic of Germany           26
# Switzerland                           22
# Japan                                 18
# Sweden                                17
# USSR                                  11
# the Netherlands                       11
# Denmark                                9
# Canada                                 7
# Austria                                6
# Italy                                  6
# Australia                              6
# Belgium                                6
# Norway                                 5
# Israel                                 5
# Russia                                 3
# Argentina                              2
# China                                  2
# Portugal                               2
# Spain                                  1
# ...

# %%
top_10_Country = dataset['country'].value_counts()[0:10]

# %%
top_10_Country
# Out:
# USA                            361
# United Kingdom                  91
# Germany                         51
# France                          40
# Federal Republic of Germany     26
# Switzerland                     22
# Japan                           18
# Sweden                          17
# USSR                            11
# the Netherlands                 11
# Name: country, dtype: int64

# %%
dataset['bornCountry'].value_counts()[0:10].plot(kind = 'bar')
plt.title("Top 10 Country which have most number of nobel prize recipients ")
plt.ylabel("Frequency")
plt.xlabel("Country")
plt.show()

# %%
dataset['year'].value_counts().sort_index(ascending=True)
# Out:
# 1901.0     6
# 1902.0     7
# 1903.0     7
# 1904.0     6
# 1905.0     5
#           ..
# 2012.0    15
# 2013.0    16
# 2014.0    15
# 2015.0    13
# 2016.0     8
# Name: year, Length: 113, dtype: int64

# %%
dataset_nobel.isnull().sum()
# Out:
# id                     0
# firstname              6
# surname               36
# born                  26
# died                  26
# bornCountry           32
# bornCountryCode       32
# bornCity              34
# diedCountry          371
# diedCountryCode      372
# diedCity             377
# gender                 0
# year                   6
# category               6
# overallMotivation    956
# share                  6
# motivation            94
# name                 252
# city                 258
# country              258
# dtype: int64

# %% [markdown]
# ## Find out how many Nobel prize recipients are still alive.

# %%
dataset[dataset_nobel['died'].isnull()]
# Out:
#       id                                          firstname surname born died  \
# 946  925                          National Dialogue Quartet     NaN  NaN  NaN
# 947  893  Organisation for the Prohibition of Chemical W...     NaN  NaN  NaN
# 948  881                                European Union (EU)     NaN  NaN  NaN
# 949  818   Intergovernmental Panel on Climate Change (IPCC)     NaN  NaN  NaN
# 950  810                                       Grameen Bank     NaN  NaN  NaN
# 951  561   Pugwash Conferences on Science and World Affairs     NaN  NaN  NaN
# 952  797          International Atomic Energy Agency (IAEA)     NaN  NaN  NaN
# 953  748                              United Nations (U.N.)     NaN  NaN  NaN
# 954  564     International Campaign to Ban Landmines (ICBL)     NaN  NaN  NaN
# 955  568                           M_decins Sans Fronti�res     NaN  NaN  NaN
# 956  467  Institut de droit international (Institute of ...     NaN  NaN  NaN
# ...

# %%
dataset['died'].value_counts()
# Out:
# 0000-00-00    334
# 6/12/2012       3
# 9/8/1985        3
# 5/4/2013        2
# 8/24/2016       2
#              ...
# 8/22/1958       1
# 12/19/2004      1
# 11/5/1930       1
# 7/2/2016        1
# 1/4/1941        1
# Name: died, Length: 577, dtype: int64

# %%
dataset1 = dataset[dataset['died'] == '0000-00-00']

# %%
dataset1['gender'].value_counts()
# Out:
# male      311
# female     23
# Name: gender, dtype: int64

# %%
dataset1['gender'].value_counts().plot(kind = 'bar')
plt.title('Nobel prize recipients are still alive')
plt.ylabel('Frequency')
plt.xlabel('Gender')
plt.show()
